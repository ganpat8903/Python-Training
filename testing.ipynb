# %%
assert sum([1, 2]) == 6
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 assert sum([1, 2]) == 6
#
# AssertionError:

# %%
assert sum([1, 2]) == 6, "should be 6"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 assert sum([1, 2]) == 6, "should be 6"
#
# AssertionError: should be 6

# %%
assert sum([1, 3, 2]) == 6, "Should be 6"

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")
# Out:
# Everything passed

# %%
a=10

def fun1():
    a=20
    print(a)
    
fun1()
print(a)
# Out:
# 20
# 10

# %%
a=10

def fun2():
    # global a
    a=20
    print(a)

fun2()
print(a)
# Out:
# 20
# 20

# %%
import pprint
pprint.pprint(locals())
# Out:
# {'In': ['',
#         'a=10\n\ndef fun1():\n    a=20\n    print(a)\n\nfun1()\nprint(a)',
#         'a=10\n'
#         '\n'
#         'def fun2():\n'
#         '    global a\n'
#         '    a=20\n'
#         '    print(a)\n'
#         '\n'
#         'fun2()\n'
#         'print(a)',
#         'import pprint\npprint.pprint(locals())'],
#  'Out': {},
#  '_': '',
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '__vsc_ipynb_file__': 'c:\\Users\\ganpa\\OneDrive\\Documents\\ReverseBits\\python\\scope-in-python.ipynb',
#  '_dh': [WindowsPath('c:/Users/ganpa/OneDrive/Documents/ReverseBits/python')],
#  '_i': 'a=10\n'
#        '\n'
#        'def fun2():\n'
#        '    global a\n'
#        '    a=20\n'
#        '    print(a)\n'
#        '\n'
#        'fun2()\n'
#        'print(a)',
#  '_i1': 'a=10\n\ndef fun1():\n    a=20\n    print(a)\n    \nfun1()\nprint(a)',
#  '_i2': 'a=10\n'
#         '\n'
#         'def fun2():\n'
#         '    global a\n'
#         '    a=20\n'
#         '    print(a)\n'
#         '\n'
#         'fun2()\n'
#         'print(a)',
#  '_i3': 'import pprint\npprint.pprint(locals())',
#  '_ih': ['',
#          'a=10\n\ndef fun1():\n    a=20\n    print(a)\n\nfun1()\nprint(a)',
#          'a=10\n'
#          '\n'
#          'def fun2():\n'
#          '    global a\n'
#          '    a=20\n'
#          '    print(a)\n'
#          '\n'
#          'fun2()\n'
#          'print(a)',
#          'import pprint\npprint.pprint(locals())'],
#  '_ii': 'a=10\n\ndef fun1():\n    a=20\n    print(a)\n    \nfun1()\nprint(a)',
#  '_iii': '',
#  '_oh': {},
#  'a': 20,
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000021AE7EF4C20>,
#  'fun1': <function fun1 at 0x0000021AE80767A0>,
#  'fun2': <function fun2 at 0x0000021AE8076840>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000021AE7E67380>>,
#  'open': <function open at 0x0000021AE5B14AE0>,
#  'pprint': <module 'pprint' from 'c:\\Program Files\\Python313\\Lib\\pprint.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000021AE7EF4C20>}

# %%
import pprint
def myfunc():
    a=12
    pprint.pprint(locals())

myfunc()
# Out:
# {'a': 12}

# %%
import pprint
def myfunc():
    a=12
    pprint.pprint(globals())

myfunc()
# Out:
# {'In': ['',
#         'a=10\n\ndef fun1():\n    a=20\n    print(a)\n\nfun1()\nprint(a)',
#         'a=10\n'
#         '\n'
#         'def fun2():\n'
#         '    global a\n'
#         '    a=20\n'
#         '    print(a)\n'
#         '\n'
#         'fun2()\n'
#         'print(a)',
#         'import pprint\npprint.pprint(locals())',
#         'import pprint\n'
#         'def myfunc():\n'
#         '    a=12\n'
#         '    pprint.pprint(locals())\n'
#         '\n'
#         'myfunc()',
#         'import pprint\n'
#         'def myfunc():\n'
#         '    a=12\n'
#         '    pprint.pprint(globals())\n'
#         '\n'
#         'myfunc()'],
#  'Out': {},
#  '_': '',
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '__vsc_ipynb_file__': 'c:\\Users\\ganpa\\OneDrive\\Documents\\ReverseBits\\python\\scope-in-python.ipynb',
#  '_dh': [WindowsPath('c:/Users/ganpa/OneDrive/Documents/ReverseBits/python')],
#  '_i': 'import pprint\n'
#        'def myfunc():\n'
#        '    a=12\n'
#        '    pprint.pprint(locals())\n'
#        '\n'
#        'myfunc()',
#  '_i1': 'a=10\n\ndef fun1():\n    a=20\n    print(a)\n    \nfun1()\nprint(a)',
#  '_i2': 'a=10\n'
#         '\n'
#         'def fun2():\n'
#         '    global a\n'
#         '    a=20\n'
#         '    print(a)\n'
#         '\n'
#         'fun2()\n'
#         'print(a)',
#  '_i3': 'import pprint\npprint.pprint(locals())',
#  '_i4': 'import pprint\n'
#         'def myfunc():\n'
#         '    a=12\n'
#         '    pprint.pprint(locals())\n'
#         '\n'
#         'myfunc()',
#  '_i5': 'import pprint\n'
#         'def myfunc():\n'
#         '    a=12\n'
#         '    pprint.pprint(globals())\n'
#         '\n'
#         'myfunc()',
#  '_ih': ['',
#          'a=10\n\ndef fun1():\n    a=20\n    print(a)\n\nfun1()\nprint(a)',
#          'a=10\n'
#          '\n'
#          'def fun2():\n'
#          '    global a\n'
#          '    a=20\n'
#          '    print(a)\n'
#          '\n'
#          'fun2()\n'
#          'print(a)',
#          'import pprint\npprint.pprint(locals())',
#          'import pprint\n'
#          'def myfunc():\n'
#          '    a=12\n'
#          '    pprint.pprint(locals())\n'
#          '\n'
#          'myfunc()',
#          'import pprint\n'
#          'def myfunc():\n'
#          '    a=12\n'
#          '    pprint.pprint(globals())\n'
#          '\n'
#          'myfunc()'],
#  '_ii': 'import pprint\npprint.pprint(locals())',
#  '_iii': 'a=10\n'
#          '\n'
#          'def fun2():\n'
#          '    global a\n'
#          '    a=20\n'
#          '    print(a)\n'
#          '\n'
#          'fun2()\n'
#          'print(a)',
#  '_oh': {},
#  'a': 20,
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000021AE7EF4C20>,
#  'fun1': <function fun1 at 0x0000021AE80767A0>,
#  'fun2': <function fun2 at 0x0000021AE8076840>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000021AE7E67380>>,
#  'myfunc': <function myfunc at 0x0000021AE80768E0>,
#  'open': <function open at 0x0000021AE5B14AE0>,
#  'pprint': <module 'pprint' from 'c:\\Program Files\\Python313\\Lib\\pprint.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000021AE7EF4C20>}

# %%
# %who
# Out:
# a	 fun1	 fun2	 myfunc	 pprint

# %%
# %reset

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
def square(base):
    result = base ** 2
    print(f'The square of {base} is: {result}')
    
square(10)
# print(result) NameError
# Out:
# The square of 10 is: 100

# %%
var = 100  # A global variable
def increment():
    print(var)
    # var = 1  UnboundLocalError 
    
increment()
# Out:
# 100

# %%
def myfunc(alist):
    return len(alist)

print(myfunc([1,2,3]))
# Out:
# 3

# %%
import dis
dis.dis(myfunc)
# Out:
#   1           RESUME                   0
#
#   2           LOAD_GLOBAL              1 (len + NULL)
#               LOAD_FAST                0 (alist)
#               CALL                     1
#               RETURN_VALUE

# %%
import dis

def myfunc():
    x = 5 + 3

dis.dis(myfunc)
# Out:
#   3           RESUME                   0
#
#   4           LOAD_CONST               1 (8)
#               STORE_FAST               0 (x)
#               RETURN_CONST             0 (None)

# %%
def myfunc(alist):
    return len(alist)

print(myfunc([1,2,3]))

import dis

b=dis.Bytecode(myfunc)
print(list(b))
for i in b:
    print(i.opname)
# Out:
# 3
# ...
